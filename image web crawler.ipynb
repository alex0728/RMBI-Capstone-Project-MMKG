# %%
import pandas as pd

# %%
img_des = pd.read_csv('D:\RMBI_MMKG_data\img_des.csv')
img_des
# Out:
#         LabelName                                 name  \
# 0        /m/027rn                   Dominican Republic
# 1       /m/017dcd         Mighty Morphin Power Rangers
# 2       /m/01sl1q                   Michelle Rodriguez
# 3       /m/0cnk2q     Australia national football team
# 4       /m/02_j1w                             Defender
# ...           ...                                  ...
# 14179  /m/0dlj8q2  Le Monde's 100 Books of the Century
# 14180    /m/05zp8                               Palace
# 14181   /m/024030                      Padma Vibhushan
# 14182  /m/02y_9cf                     Ethiopian Empire
# 14183    /m/0fkrk                              Grasses
#
#                                              description
# 0      The Dominican Republic is a country located on...
# 1      Mighty Morphin Power Rangers is an American su...
# 2      Mayte Michelle Rodriguez is an American actres...
# 3      The Australia men's national soccer team repre...
# ...

# %%
import os
import sys
filepath='D:\\RMBI_MMKG_data\\Bulk-Bing-Image-downloader' 
os.chdir(filepath)

for index, row in img_trunc.iterrows():
    query = row['name']
    # !python bbid.py -s "{query}" -o "{query}" --limit 10
# Out:
# FAIL: img-1920x1273-PuntaCana4.jpg
#  OK : istock-1138303642.jpg
#  OK : Dominican-Republic-Beaches.jpeg
#  OK : corales.jpg
# FAIL: q:70.jpg
#  OK : DR-Heritage-Tour-February-2020-1-5.jpg
#  OK : 69784245.jpg
#  OK : caribbean-beach-and-dominican-republ.jpg
#  OK : TAM_2187-ccb2af376cca452fbe4d84826e7.jpg
#  OK : dominican+republic+(2).jpg
#  OK : dominican-republic-resort-cover.jpg
#  OK : dominican-republic-tourism.jpg
# FAIL: Dominican-Republic-Main-Image.jpg
#  OK : MMARpromo.jpg
#  OK : Mighty-Morphin-Power-Rangers-Season-.jpg
#  OK : Mighty-Morphin-2-Main-Cover-InHyuk-L.jpeg
#  OK : Justice-League-Mighty-Morphin-Power-.jpg
#  OK : p183922_i_h10_ab.jpg
#  OK : mighty-morphin-power-rangers-annual-.jpeg
#  OK : thumb-1920-781416.jpg
#  OK : 915DFazMgtL._AC_SL1500_.jpg
#  OK : 0622WKDGENZLINGER-superJumbo.jpg
#  OK : Mighty-Morphin-Power-Rangers-Vol.13.jpg
# SKIP: Invalid image, not saving mighty-morphin-power-rangers-new-com.jpg
# ...
