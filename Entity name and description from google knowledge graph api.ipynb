# %%
import pandas as pd
img_link = pd.read_csv('D:\RMBI_MMKG_data\img_link.csv')
img_link
# Out:
#        LabelName           ImageID
# 0       /m/09j2d  0000201cd362f303
# 1       /m/02wbm  000032046c3f8371
# 2        /m/0k4j  0000575f5a03db70
# 3        /m/0k4j  0000599864fd15b3
# 4        /m/0k4j  00005bf623ff1ac2
# ...          ...               ...
# 323232  /m/09j2d  ffff48145fc0c38c
# 323233   /m/0jbk  ffff7c3aef15369f
# 323234  /m/09j2d  ffff83c6a0e1c6c0
# 323235  /m/026t6  ffffc57f50b5325b
# 323236   /m/0k4j  ffffeac7d2f37489
#
# [323237 rows x 2 columns]

# %%
img_link_nodup = img_link.drop_duplicates(subset=['LabelName'])
img_link_nodup
# Out:
#         LabelName           ImageID
# 0        /m/09j2d  0000201cd362f303
# 1        /m/02wbm  000032046c3f8371
# 2         /m/0k4j  0000575f5a03db70
# 5        /m/06msq  00008206f111b234
# 6        /m/07c52  000085351f54575c
# 8        /m/07jdr  000090744f4a1ffc
# 13       /m/07y_7  0000aa810854dc2e
# 14      /m/0bt9lr  0000b9fcba019d36
# 18       /m/01yrx  0000de486dc6c49f
# 19       /m/07bgp  0000f2101250b009
# 23      /m/0fj52s  00013bb4b9ddfbab
# 24       /m/029tx  0001544a14436a9d
# 25       /m/015p6  0001be3e7d78372e
# 30       /m/0cxn2  0001cb734adac2ee
# 33        /m/0jbk  0001f07fff1769c3
# 39       /m/0342h  0002a3c01c926a49
# 50       /m/09728  000323390354c939
# 98       /m/07j87  0006124f7e35107e
# 119      /m/026t6  0007661d46e94768
# 163      /m/09b5t  000a816392d086c4
# 166      /m/07gql  000aa1d02ddf1f99
# 207     /m/014j1m  000d9c59687b509b
# 220      /m/0hkxq  000e1654f1d9b2cb
# 222     /m/013y1f  000e22003b693292
# 278      /m/03k3r  0011a9e33cde56fc
# ...

# %%
import json
import urllib

img_des = pd.DataFrame(columns=['LabelName','name','description'])

for index, row in img_link_nodup.iterrows():
    api_key = "AIzaSyB4rJ3gScCzeY2Offyc0fsI9UpwsddWlAw"
    mid = row['LabelName']
    service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
    params = {
        'ids': mid,
        'limit': 10,
        'indent': True,
        'key': api_key,
    }
    url = service_url + '?' + urllib.parse.urlencode(params)
    response = json.loads(urllib.request.urlopen(url).read())
    for element in response['itemListElement']:
        r={'LabelName': mid,'name': element['result']['name'],'description': element['result']['detailedDescription']['articleBody']}
        img_des = img_des.append(r, ignore_index = True)

# %%
img_des
# Out:
#      LabelName              name  \
# 0     /m/09j2d          Clothing
# 1     /m/02wbm              Food
# 2      /m/0k4j               Car
# 3     /m/06msq         Sculpture
# 4     /m/07c52        Television
# 5     /m/07jdr             Train
# 6     /m/07y_7            Violin
# 7    /m/0bt9lr               Dog
# 8     /m/01yrx               Cat
# 9     /m/029tx          Dinosaur
# 10    /m/015p6             Birds
# 11    /m/0cxn2         Ice cream
# 12     /m/0jbk            Animal
# 13    /m/0342h            Guitar
# 14    /m/09728             Bread
# 15    /m/07j87            Tomato
# 16    /m/026t6              Drum
# 17    /m/09b5t           Chicken
# 18    /m/07gql           Trumpet
# 19   /m/014j1m             Apple
# 20   /m/013y1f             Organ
# 21    /m/03k3r             Horse
# 22    /m/0663v             Pizza
# 23  /m/01xq0k1            Cattle
# 24    /m/05z55             Pasta
# 25    /m/057cc  Musical keyboard
# 26     /m/0mkg         Accordion
# ...

# %%
img_link
# Out:
#        LabelName           ImageID
# 0       /m/09j2d  0000201cd362f303
# 1       /m/02wbm  000032046c3f8371
# 2        /m/0k4j  0000575f5a03db70
# 3        /m/0k4j  0000599864fd15b3
# 4        /m/0k4j  00005bf623ff1ac2
# ...          ...               ...
# 323232  /m/09j2d  ffff48145fc0c38c
# 323233   /m/0jbk  ffff7c3aef15369f
# 323234  /m/09j2d  ffff83c6a0e1c6c0
# 323235  /m/026t6  ffffc57f50b5325b
# 323236   /m/0k4j  ffffeac7d2f37489
#
# [323237 rows x 2 columns]

# %%
entity_name_des = pd.merge(img_link, img_des, on=['LabelName'])

# %%
entity_name_des
# Out:
#        LabelName           ImageID         name  \
# 0       /m/09j2d  0000201cd362f303     Clothing
# 1       /m/09j2d  00008d167563158c     Clothing
# 2       /m/09j2d  00009cadede2ed69     Clothing
# 3       /m/09j2d  0000a1b2fba255e9     Clothing
# 4       /m/09j2d  0000ce19115ae401     Clothing
# ...          ...               ...          ...
# 321376  /m/0319l  ee4d310649e0dd9f  French horn
# 321377  /m/0319l  eeb0bc42c48f8650  French horn
# 321378  /m/0319l  f1e8575047cb09b5  French horn
# 321379  /m/0319l  fbd39a0feabe98e7  French horn
# 321380  /m/0319l  fd840c590914c1ed  French horn
#
#                                               description
# 0       Clothing are items worn on the body. Typically...
# 1       Clothing are items worn on the body. Typically...
# 2       Clothing are items worn on the body. Typically...
# 3       Clothing are items worn on the body. Typically...
# 4       Clothing are items worn on the body. Typically...
# ...

# %%
entity_name_des['ImageID'] = entity_name_des['ImageID'] +'.jpg'

# %%
entity_name_des
# Out:
#        LabelName               ImageID         name  \
# 0       /m/09j2d  0000201cd362f303.jpg     Clothing
# 1       /m/09j2d  00008d167563158c.jpg     Clothing
# 2       /m/09j2d  00009cadede2ed69.jpg     Clothing
# 3       /m/09j2d  0000a1b2fba255e9.jpg     Clothing
# 4       /m/09j2d  0000ce19115ae401.jpg     Clothing
# ...          ...                   ...          ...
# 321376  /m/0319l  ee4d310649e0dd9f.jpg  French horn
# 321377  /m/0319l  eeb0bc42c48f8650.jpg  French horn
# 321378  /m/0319l  f1e8575047cb09b5.jpg  French horn
# 321379  /m/0319l  fbd39a0feabe98e7.jpg  French horn
# 321380  /m/0319l  fd840c590914c1ed.jpg  French horn
#
#                                               description
# 0       Clothing are items worn on the body. Typically...
# 1       Clothing are items worn on the body. Typically...
# 2       Clothing are items worn on the body. Typically...
# 3       Clothing are items worn on the body. Typically...
# ...

# %%
entity_name_des.to_csv('D:\RMBI_MMKG_data\entity_name_des.csv',index=False)

# %%
entity_name_des_trunc = entity_name_des.sample(n=1000, random_state=1)

# %%
entity_name_des_trunc
# Out:
#        LabelName               ImageID       name  \
# 48722   /m/09j2d  5975e5e6973ca2ad.jpg   Clothing
# 272079  /m/01yrx  bfe93a5657824d86.jpg        Cat
# 37478   /m/09j2d  44784a16118b2bc0.jpg   Clothing
# 186757   /m/0k4j  673aef54336cf496.jpg        Car
# 55064   /m/09j2d  64fdc83210da5cee.jpg   Clothing
# ...          ...                   ...        ...
# 234505  /m/06msq  09fc7ac0ae728478.jpg  Sculpture
# 268134  /m/01yrx  4a0ebed614054324.jpg        Cat
# 59681   /m/09j2d  6dc01a5376d7f23e.jpg   Clothing
# 177194   /m/0k4j  493ee5a73b5863de.jpg        Car
# 202125   /m/0k4j  983897722524a451.jpg        Car
#
#                                               description
# 48722   Clothing are items worn on the body. Typically...
# 272079  The cat is a domestic species of a small carni...
# 37478   Clothing are items worn on the body. Typically...
# 186757  A car is a wheeled motor vehicle used for tran...
# 55064   Clothing are items worn on the body. Typically...
# ...

# %%
entity_name_des_trunc.to_csv('D:\RMBI_MMKG_data\entity_name_des_trunc.csv',index=False)
